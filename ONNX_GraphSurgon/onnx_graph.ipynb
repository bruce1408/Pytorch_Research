# %%
import onnx
import torch

# %%
MODEL_PATH="/home/bruce_ultra/workspace/onnx_models/resnet50.onnx"
model = onnx.load(MODEL_PATH)

# %%
model.graph.node
# Out:
# [input: "input"
# input: "conv1.weight"
# output: "321"
# name: "Conv_0"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 7
#   ints: 7
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 3
#   ints: 3
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "321"
# input: "bn1.weight"
# input: "bn1.bias"
# input: "bn1.running_mean"
# input: "bn1.running_var"
# output: "322"
# name: "BatchNormalization_1"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-06
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.8999999761581421
#   type: FLOAT
# }
# , input: "322"
# output: "323"
# name: "Relu_2"
# op_type: "Relu"
# , input: "323"
# output: "324"
# name: "MaxPool_3"
# op_type: "MaxPool"
# ...

# %%
input_attr = model.graph.input
for input_node in input_attr:
    print(input_node.name)
    print("====== \n", input_node.type)
# Out:
# input
# ...
#  tensor_type {
#   elem_type: 1
#   shape {
#     dim {
#       dim_value: 1
#     }
#     dim {
#       dim_value: 3
#     }
#     dim {
#       dim_value: 224
#     }
#     dim {
#       dim_value: 224
#     }
#   }
# }

# %%
input_attr
# Out:
# [name: "input"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 3
#       }
#       dim {
#         dim_value: 224
#       }
#       dim {
#         dim_value: 224
#       }
#     }
#   }
# }
# ]

# %%
model.graph.output
# Out:
# [name: "output"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 1000
#       }
#     }
#   }
# }
# ]

# %%
model.graph.output[0].name
# Out:
# 'output'

# %%
model.graph.doc_string
# Out:
# ''

# %%
for node in model.graph.node:
    print(node.name)
    print(node.op_type)
# Out:
# Conv_0
# Conv
# BatchNormalization_1
# BatchNormalization
# Relu_2
# Relu
# MaxPool_3
# MaxPool
# Conv_4
# Conv
# BatchNormalization_5
# BatchNormalization
# Relu_6
# Relu
# Conv_7
# Conv
# BatchNormalization_8
# BatchNormalization
# Relu_9
# Relu
# Conv_10
# Conv
# BatchNormalization_11
# BatchNormalization
# Conv_12
# Conv
# BatchNormalization_13
# BatchNormalization
# Add_14
# Add
# Relu_15
# Relu
# Conv_16
# Conv
# BatchNormalization_17
# BatchNormalization
# Relu_18
# Relu
# Conv_19
# Conv
# BatchNormalization_20
# BatchNormalization
# Relu_21
# Relu
# Conv_22
# Conv
# BatchNormalization_23
# BatchNormalization
# Add_24
# Add
# Relu_25
# Relu
# Conv_26
# Conv
# BatchNormalization_27
# BatchNormalization
# Relu_28
# Relu
# Conv_29
# Conv
# BatchNormalization_30
# BatchNormalization
# Relu_31
# Relu
# Conv_32
# Conv
# BatchNormalization_33
# BatchNormalization
# Add_34
# Add
# Relu_35
# Relu
# Conv_36
# Conv
# BatchNormalization_37
# BatchNormalization
# Relu_38
# Relu
# Conv_39
# ...

# %%
model.graph.output
# Out:
# [name: "output"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 1000
#       }
#     }
#   }
# }
# ]

# %%
model.graph.name
# Out:
# 'torch-jit-export'

# %%
# 5. 初始化权重和常量
for init in model.graph.initializer:
    print(f"Initializer: {init.name}, Shape: {init.dims}")
# Out:
# Initializer: bn1.bias, Shape: [64]
# Initializer: bn1.running_mean, Shape: [64]
# Initializer: bn1.running_var, Shape: [64]
# Initializer: bn1.weight, Shape: [64]
# Initializer: conv1.weight, Shape: [64, 3, 7, 7]
# Initializer: fc.bias, Shape: [1000]
# Initializer: fc.weight, Shape: [1000, 2048]
# Initializer: layer1.0.bn1.bias, Shape: [64]
# Initializer: layer1.0.bn1.running_mean, Shape: [64]
# Initializer: layer1.0.bn1.running_var, Shape: [64]
# Initializer: layer1.0.bn1.weight, Shape: [64]
# Initializer: layer1.0.bn2.bias, Shape: [64]
# Initializer: layer1.0.bn2.running_mean, Shape: [64]
# Initializer: layer1.0.bn2.running_var, Shape: [64]
# Initializer: layer1.0.bn2.weight, Shape: [64]
# Initializer: layer1.0.bn3.bias, Shape: [256]
# Initializer: layer1.0.bn3.running_mean, Shape: [256]
# Initializer: layer1.0.bn3.running_var, Shape: [256]
# Initializer: layer1.0.bn3.weight, Shape: [256]
# Initializer: layer1.0.conv1.weight, Shape: [64, 64, 1, 1]
# ...
